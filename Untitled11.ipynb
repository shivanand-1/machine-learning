# %%
import pandas as pd
from sklarn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()

# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
import pandas as pd
df = pd.DataFrame({
    "Name": ["Rahul", "Anita", "Kiran", "Sneha", "Arjun",
             "Meena", "Ravi", "Pooja", "Vikas", "Neha"],

    "Education": ["School", "Diploma", "Bachelor", "Master", "PhD",
                  "Bachelor", "Diploma", "Master", "School", "PhD"],

    "Experience_Level": ["Beginner", "Intermediate", "Advanced", "Advanced", "Expert",
                         "Intermediate", "Beginner", "Expert", "Beginner", "Advanced"],

    "Performance": ["Low", "Medium", "High", "High", "Excellent",
                    "Medium", "Low", "Excellent", "Low", "High"]
})
cat=["Low", "Medium", "High","Excellent"]
oe=OrdinalEncoder(categories=[["Low", "Medium", "High","Excellent"],["Beginner", "Intermediate", "Advanced","Expert"]])
dfaa=oe.fit_transform(df[["Performance","Experience_Level"]])
dfaa
# Out:
# array([[0., 0.],
#        [1., 1.],
#        [2., 2.],
#        [2., 2.],
#        [3., 3.],
#        [1., 1.],
#        [0., 0.],
#        [3., 3.],
#        [0., 0.],
#        [2., 2.]])

# %%
import pandas as pd

# Small dataset for practice
df = pd.DataFrame({
    "Student": ["Aman", "Riya", "Kiran", "Pooja", "Rahul"],

    "Grade": ["Poor", "Average", "Good", "Excellent", "Good"],

    "Attendance": ["Low", "Medium", "High", "High", "Medium"]
})

print(df)
# Out:
#   Student      Grade Attendance
# 0    Aman       Poor        Low
# 1    Riya    Average     Medium
# 2   Kiran       Good       High
# 3   Pooja  Excellent       High
# 4   Rahul       Good     Medium

# %%
so=df.sort_values("Grade")
print(so)
encoding=OrdinalEncoder(categories=ca)
enn=encoding.fit_transform(df[["Grade"]])
# Out:
#   Student      Grade Attendance
# 1    Riya    Average     Medium
# 3   Pooja  Excellent       High
# 2   Kiran       Good       High
# 4   Rahul       Good     Medium
# 0    Aman       Poor        Low
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[48], line 4
#       2 print(so)
#       3 encoding=OrdinalEncoder(categories=ca)
# ----> 4 enn=encoding.fit_transform(df[["Grade"]])
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
# ...

# %%
df[["Performance"],df["Experience
# Out:
#   Cell In[63], line 1
#     df[["Performance"],df["Experience_Level"]
#                                              ^
# SyntaxError: incomplete input
