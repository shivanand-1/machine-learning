# %%
import pandas as pd

data = {
    "Name": ["Ram", "Sham", "John", "Aman", "Ravi"],
    "Marks": [85, 90, 78, 92, 88]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Name  Marks
# 0   Ram     85
# 1  Sham     90
# 2  John     78
# 3  Aman     92
# 4  Ravi     88

# %%
for i in set(df["Name"]):
    df[f"Name_{i}"]=[1 if k==i else 0 for k in df["Name"]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 3
#       1 for i in set(df["Name"]):
#       2     df[f"Name_{i}"]=[1 if k==i else 0 for k in df["Name"]]
# ----> 3 pd.reset_index(df.columns)
#
# AttributeError: module 'pandas' has no attribute 'reset_index'
