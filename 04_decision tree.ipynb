# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
data=load_breast_cancer()
X=data.data
y=data.target

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
model=DecisionTreeClassifier()

# %%
parmeter = {
    "max_depth": [5, 10, 20, 30],
    "criterion": ["gini", "entropy"]
}

# %%
mode=GridSearchCV(model,parmeter,cv=5)
mode.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 10, 20, 30]})

# %%
mode.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 30}

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
tree.plot_tree(mode.best_estimator_, filled=True, feature_names=data.feature_names, class_names=data.target_names)
# Out:
# [Text(0.625, 0.9375, 'mean concave points <= 0.051\nentropy = 0.951\nsamples = 426\nvalue = [158, 268]\nclass = benign'),
#  Text(0.3611111111111111, 0.8125, 'worst radius <= 16.83\nentropy = 0.327\nsamples = 267\nvalue = [16, 251]\nclass = benign'),
#  Text(0.4930555555555556, 0.875, 'True  '),
#  Text(0.2222222222222222, 0.6875, 'radius error <= 0.626\nentropy = 0.142\nsamples = 249\nvalue = [5, 244]\nclass = benign'),
#  Text(0.1111111111111111, 0.5625, 'worst texture <= 30.145\nentropy = 0.095\nsamples = 246\nvalue = [3, 243]\nclass = benign'),
#  Text(0.05555555555555555, 0.4375, 'entropy = 0.0\nsamples = 213\nvalue = [0, 213]\nclass = benign'),
#  Text(0.16666666666666666, 0.4375, 'worst area <= 641.6\nentropy = 0.439\nsamples = 33\nvalue = [3, 30]\nclass = benign'),
#  Text(0.1111111111111111, 0.3125, 'entropy = 0.0\nsamples = 23\nvalue = [0, 23]\nclass = benign'),
#  Text(0.2222222222222222, 0.3125, 'mean radius <= 13.45\nentropy = 0.881\nsamples = 10\nvalue = [3, 7]\nclass = benign'),
#  Text(0.16666666666666666, 0.1875, 'mean texture <= 28.79\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = malignant'),
#  Text(0.1111111111111111, 0.0625, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = malignant'),
#  Text(0.2222222222222222, 0.0625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = benign'),
#  Text(0.2777777777777778, 0.1875, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = benign'),
#  Text(0.3333333333333333, 0.5625, 'mean smoothness <= 0.091\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = malignant'),
#  Text(0.2777777777777778, 0.4375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = benign'),
#  Text(0.3888888888888889, 0.4375, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = malignant'),
#  Text(0.5, 0.6875, 'mean texture <= 16.19\nentropy = 0.964\nsamples = 18\nvalue = [11, 7]\nclass = malignant'),
#  Text(0.4444444444444444, 0.5625, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = benign'),
#  Text(0.5555555555555556, 0.5625, 'concave points error <= 0.01\nentropy = 0.619\nsamples = 13\nvalue = [11, 2]\nclass = malignant'),
#  Text(0.5, 0.4375, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = malignant'),
#  Text(0.6111111111111112, 0.4375, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = benign'),
#  Text(0.8888888888888888, 0.8125, 'worst perimeter <= 114.45\nentropy = 0.491\nsamples = 159\nvalue = [142, 17]\nclass = malignant'),
#  Text(0.7569444444444444, 0.875, '  False'),
#  Text(0.8333333333333334, 0.6875, 'worst texture <= 25.655\nentropy = 0.979\nsamples = 41\nvalue = [24, 17]\nclass = malignant'),
#  Text(0.7777777777777778, 0.5625, 'worst concave points <= 0.166\nentropy = 0.485\nsamples = 19\nvalue = [2, 17]\nclass = benign'),
#  Text(0.7222222222222222, 0.4375, 'entropy = 0.0\nsamples = 17\nvalue = [0, 17]\nclass = benign'),
#  Text(0.8333333333333334, 0.4375, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = malignant'),
#  Text(0.8888888888888888, 0.5625, 'entropy = 0.0\nsamples = 22\nvalue = [22, 0]\nclass = malignant'),
#  Text(0.9444444444444444, 0.6875, 'entropy = 0.0\nsamples = 118\nvalue = [118, 0]\nclass = malignant')]
